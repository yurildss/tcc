# %%
#baixar os dados

# %%
#Download da base de dados MIT-BIH Arrhythmia Database direto do PhisioNet
import wfdb

# Nome do dataset no PhysioNet
database = "mitdb"

# Pasta onde será salvo
target_folder = "./mitbih"

# Faz o download completo
wfdb.dl_database(database, dl_dir=target_folder)

print("Download concluído!")
# Out:
# Generating record list for: 100
# Generating record list for: 101
# Generating record list for: 102
# Generating record list for: 103
# Generating record list for: 104
# Generating record list for: 105
# Generating record list for: 106
# Generating record list for: 107
# Generating record list for: 108
# Generating record list for: 109
# Generating record list for: 111
# Generating record list for: 112
# Generating record list for: 113
# Generating record list for: 114
# Generating record list for: 115
# Generating record list for: 116
# Generating record list for: 117
# Generating record list for: 118
# Generating record list for: 119
# Generating record list for: 121
# Generating record list for: 122
# Generating record list for: 123
# Generating record list for: 124
# Generating record list for: 200
# Generating record list for: 201
# Generating record list for: 202
# Generating record list for: 203
# Generating record list for: 205
# Generating record list for: 207
# Generating record list for: 208
# Generating record list for: 209
# Generating record list for: 210
# Generating record list for: 212
# Generating record list for: 213
# Generating record list for: 214
# Generating record list for: 215
# Generating record list for: 217
# Generating record list for: 219
# Generating record list for: 220
# Generating record list for: 221
# Generating record list for: 222
# Generating record list for: 223
# Generating record list for: 228
# Generating record list for: 230
# Generating record list for: 231
# Generating record list for: 232
# Generating record list for: 233
# Generating record list for: 234
# Generating list of all files for: 100
# Generating list of all files for: 101
# Generating list of all files for: 102
# Generating list of all files for: 103
# Generating list of all files for: 104
# Generating list of all files for: 105
# Generating list of all files for: 106
# Generating list of all files for: 107
# Generating list of all files for: 108
# Generating list of all files for: 109
# Generating list of all files for: 111
# Generating list of all files for: 112
# Generating list of all files for: 113
# Generating list of all files for: 114
# Generating list of all files for: 115
# Generating list of all files for: 116
# Generating list of all files for: 117
# Generating list of all files for: 118
# Generating list of all files for: 119
# Generating list of all files for: 121
# Generating list of all files for: 122
# Generating list of all files for: 123
# Generating list of all files for: 124
# Generating list of all files for: 200
# Generating list of all files for: 201
# Generating list of all files for: 202
# Generating list of all files for: 203
# Generating list of all files for: 205
# Generating list of all files for: 207
# Generating list of all files for: 208
# Generating list of all files for: 209
# Generating list of all files for: 210
# Generating list of all files for: 212
# Generating list of all files for: 213
# Generating list of all files for: 214
# Generating list of all files for: 215
# Generating list of all files for: 217
# Generating list of all files for: 219
# Generating list of all files for: 220
# Generating list of all files for: 221
# Generating list of all files for: 222
# Generating list of all files for: 223
# Generating list of all files for: 228
# Generating list of all files for: 230
# Generating list of all files for: 231
# Generating list of all files for: 232
# Generating list of all files for: 233
# Generating list of all files for: 234
# Created local base download directory: ./mitbih
# Downloading files...
# Finished downloading files
# Download concluído!

# %%
#analisar o que foi baixado

# %%
import pandas as pd
import os
import wfdb

# Pasta onde os arquivos do MIT-BIH estão
data_folder = "mitbih"

# Pega todos os arquivos .dat (cada record tem .dat, .hea e .atr)
records = [os.path.splitext(f)[0] for f in os.listdir(data_folder) if f.endswith(".dat")]

# Remove duplicatas e ordena
records = sorted(set(records))

print("Registros encontrados:", records)

# Pasta para salvar os CSVs
output_folder = "mit-bih-arrhythmia-database-1.0.0"
os.makedirs(output_folder, exist_ok=True)
print("Criação da pasta concluida")
# Out:
# Registros encontrados: ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '111', '112', '113', '114', '115', '116', '117', '118', '119', '121', '122', '123', '124', '200', '201', '202', '203', '205', '207', '208', '209', '210', '212', '213', '214', '215', '217', '219', '220', '221', '222', '223', '228', '230', '231', '232', '233', '234']
# Criação da pasta concluida

# %%
#anotação dos dados

# %%
for rec_name in records:
    print(f"Processando registro {rec_name}...")

    # Lê o sinal
    record = wfdb.rdrecord(os.path.join(data_folder, rec_name))
    signal = record.p_signal  # array numpy, cada coluna = canal

    # Lê as anotações
    annotation = wfdb.rdann(os.path.join(data_folder, rec_name), 'atr')

    # Cria DataFrame com todas as amostras
    df = pd.DataFrame(signal, columns=[f"channel_{i}" for i in range(signal.shape[1])])
    df["sample #"] = range(len(df))
    df["type"] = "NC"  # default sem anotação

    # Marca os batimentos anotados
    for s, t in zip(annotation.sample, annotation.symbol):
        if s < len(df):
            df.loc[s, "type"] = t

    # Salva CSV
    output_csv = os.path.join(output_folder, f"{rec_name}_labeled.csv")
    df.to_csv(output_csv, index=False)

    print(f"{rec_name}_labeled.csv criado!")
# Out:
# Processando registro 100...
# 100_labeled.csv criado!
# Processando registro 101...
# 101_labeled.csv criado!
# Processando registro 102...
# 102_labeled.csv criado!
# Processando registro 103...
# 103_labeled.csv criado!
# Processando registro 104...
# 104_labeled.csv criado!
# Processando registro 105...
# 105_labeled.csv criado!
# Processando registro 106...
# 106_labeled.csv criado!
# Processando registro 107...
# 107_labeled.csv criado!
# Processando registro 108...
# 108_labeled.csv criado!
# Processando registro 109...
# 109_labeled.csv criado!
# Processando registro 111...
# 111_labeled.csv criado!
# Processando registro 112...
# 112_labeled.csv criado!
# Processando registro 113...
# 113_labeled.csv criado!
# Processando registro 114...
# 114_labeled.csv criado!
# Processando registro 115...
# 115_labeled.csv criado!
# Processando registro 116...
# 116_labeled.csv criado!
# Processando registro 117...
# 117_labeled.csv criado!
# Processando registro 118...
# 118_labeled.csv criado!
# Processando registro 119...
# 119_labeled.csv criado!
# Processando registro 121...
# 121_labeled.csv criado!
# Processando registro 122...
# 122_labeled.csv criado!
# Processando registro 123...
# 123_labeled.csv criado!
# Processando registro 124...
# 124_labeled.csv criado!
# Processando registro 200...
# 200_labeled.csv criado!
# Processando registro 201...
# 201_labeled.csv criado!
# Processando registro 202...
# 202_labeled.csv criado!
# Processando registro 203...
# 203_labeled.csv criado!
# Processando registro 205...
# 205_labeled.csv criado!
# Processando registro 207...
# 207_labeled.csv criado!
# Processando registro 208...
# 208_labeled.csv criado!
# Processando registro 209...
# 209_labeled.csv criado!
# Processando registro 210...
# 210_labeled.csv criado!
# Processando registro 212...
# 212_labeled.csv criado!
# Processando registro 213...
# 213_labeled.csv criado!
# Processando registro 214...
# 214_labeled.csv criado!
# Processando registro 215...
# 215_labeled.csv criado!
# Processando registro 217...
# 217_labeled.csv criado!
# Processando registro 219...
# 219_labeled.csv criado!
# Processando registro 220...
# 220_labeled.csv criado!
# Processando registro 221...
# 221_labeled.csv criado!
# Processando registro 222...
# 222_labeled.csv criado!
# Processando registro 223...
# 223_labeled.csv criado!
# Processando registro 228...
# 228_labeled.csv criado!
# Processando registro 230...
# 230_labeled.csv criado!
# Processando registro 231...
# 231_labeled.csv criado!
# Processando registro 232...
# 232_labeled.csv criado!
# Processando registro 233...
# 233_labeled.csv criado!
# Processando registro 234...
# 234_labeled.csv criado!

# %%
#juntar todos os dados em um unico csv

# %%
import pandas as pd
import os

# Pasta CSV
csv_folder = "mit-bih-arrhythmia-database-1.0.0"

# %%
# Lista todos os arquivos .csv da pasta em ordem alfabética
csv_files = sorted(
    [os.path.join(csv_folder, f) for f in os.listdir(csv_folder) if f.endswith(".csv")]
)
print(csv_files)
# Out:
# ['mit-bih-arrhythmia-database-1.0.0/100_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/101_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/102_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/103_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/104_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/105_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/106_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/107_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/108_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/109_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/111_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/112_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/113_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/114_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/115_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/116_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/117_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/118_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/119_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/121_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/122_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/123_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/124_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/200_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/201_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/202_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/203_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/205_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/207_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/208_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/209_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/210_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/212_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/213_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/214_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/215_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/217_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/219_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/220_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/221_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/222_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/223_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/228_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/230_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/231_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/232_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/233_labeled.csv', 'mit-bih-arrhythmia-database-1.0.0/234_labeled.csv']

# %%
# Lê e concatena tudo em um único DataFrame
df_list = []
for file in csv_files:
    temp_df = pd.read_csv(file)
    
    # adiciona coluna extra para saber de qual registro veio
    record_name = os.path.splitext(os.path.basename(file))[0]
    temp_df["record"] = record_name  
    
    df_list.append(temp_df)

df_all = pd.concat(df_list, ignore_index=True)

# Salva em um único CSV
df_all.to_csv("mitbih_all_records.csv", index=False)

print("Arquivo único gerado: mitbih_all_records.csv")
# Out:
# Arquivo único gerado: mitbih_all_records.csv

# %%
# Contagem de cada tipo
# Carregar a planilha unificada
df = pd.read_csv("mitbih_all_records.csv")
contagem = df["type"].value_counts()

print(contagem)
# Out:
# type
# NC    31087353
# N        75052
# L         8075
# R         7259
# V         7130
# /         7028
# A         2546
# +         1291
# f          982
# F          803
# ~          616
# !          472
# "          437
# j          229
# x          193
# a          150
# |          132
# E          106
# J           83
# Q           33
# e           16
# [            6
# ]            6
# S            2
# Name: count, dtype: int64

# %%
#limpeza de dados

# %%
# Carregar a planilha
df = pd.read_csv("mitbih_all_records.csv")

# Lista de tipos relevantes (batimentos cardíacos)
tipos_relevantes = ["N", "L", "R", "V", "A", "F", "S", "Q", "/", "f", "NC"]

# Filtrar somente esses tipos
df_filtrado = df[df["type"].isin(tipos_relevantes)]

# Salvar em novo arquivo
df_filtrado.to_csv("batimentos_filtrados.csv", index=False)

print("Linhas originais:", len(df))
print("Linhas após filtragem:", len(df_filtrado))
# Out:
# Linhas originais: 31200000
# Linhas após filtragem: 31196263

# %%
# Carregar a planilha
df = pd.read_csv("batimentos_filtrados.csv")

# Contagem de cada tipo
contagem = df["type"].value_counts()

print(contagem)
# Out:
# type
# NC    31087353
# N        75052
# L         8075
# R         7259
# V         7130
# /         7028
# A         2546
# f          982
# F          803
# Q           33
# S            2
# Name: count, dtype: int64

# %%
df.head(20)
# Out:
#     channel_0  channel_1  sample # type       record
# 0      -0.145     -0.065         0   NC  100_labeled
# 1      -0.145     -0.065         1   NC  100_labeled
# 2      -0.145     -0.065         2   NC  100_labeled
# 3      -0.145     -0.065         3   NC  100_labeled
# 4      -0.145     -0.065         4   NC  100_labeled
# 5      -0.145     -0.065         5   NC  100_labeled
# 6      -0.145     -0.065         6   NC  100_labeled
# 7      -0.145     -0.065         7   NC  100_labeled
# 8      -0.120     -0.080         8   NC  100_labeled
# 9      -0.135     -0.080         9   NC  100_labeled
# 10     -0.145     -0.085        10   NC  100_labeled
# 11     -0.150     -0.085        11   NC  100_labeled
# 12     -0.160     -0.075        12   NC  100_labeled
# 13     -0.155     -0.070        13   NC  100_labeled
# 14     -0.160     -0.070        14   NC  100_labeled
# 15     -0.175     -0.065        15   NC  100_labeled
# 16     -0.180     -0.055        16   NC  100_labeled
# 17     -0.185     -0.050        17   NC  100_labeled
# 18     -0.155     -0.040        19   NC  100_labeled
# 19     -0.175     -0.040        20   NC  100_labeled

# %%
contagem = df["sample #"]

# %%
ultimo_valor = contagem.tail(1).values[0]

# %%
print(ultimo_valor)
# Out:
# 649999
